# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaavyesh/oasis_infobyte_task-5/blob/main/Task_5_sales_prediction_oasis_infobyte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# #Reading the dataset

# %%
path  = '/content/drive/MyDrive/oasis infobyte /Advertising.csv'
df = pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# #Splitting the dataset into training and testing sets

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 42)

# %%
x_train.shape
# Out:
# (140, 3)

# %%
y_train.shape
# Out:
# (140,)

# %%
model = RandomForestRegressor(n_estimators=100,random_state=42)

# %% [markdown]
# #Training the model

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model.score(x_train,y_train)
# Out:
# 0.995873563530373

# %% [markdown]
# #Predicting the sales values for testing data

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.9831207131396928
